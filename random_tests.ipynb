# %%
import pandas as pd
import numpy as np
import datetime

# %%
weather_training_data=pd.read_csv("weather_training_data_sg.csv",index_col=0)

# %%
aqi_training_data=pd.read_csv("aqi_training_data.csv",index_col=0)

# %%
aqi_training_data.head().shift(1)
# Out:
#      datetime   aqi
# 0        None   NaN
# 1  17/12/2022  29.0
# 2  18/12/2022  33.0
# 3  19/12/2022  29.0
# 4  20/12/2022  27.0

# %%
weather_training_data.shape
# Out:
# (41, 36)

# %%
aqi_training_data.shape
# Out:
# (30, 2)

# %%
weather_training_data["datetime"][2]>weather_training_data["datetime"][1]
# Out:
# True

# %%
aqi_training_data["datetime"]=aqi_training_data["datetime"].apply(lambda x:datetime.datetime.strptime(x,"%d/%m/%Y"))

# %%
weather_training_data["datetime"]=weather_training_data["datetime"].apply(lambda x:datetime.datetime.strptime(x,"%Y-%m-%d"))

# %%
shift=2
later_date=max(min(aqi_training_data["datetime"]),min(weather_training_data["datetime"]))
later_date
# Out:
# Timestamp('2022-12-17 00:00:00')

# %%
start_date=later_date+datetime.timedelta(days=shift)

# %%
start_date
# Out:
# Timestamp('2022-12-19 00:00:00')

# %%
#truncate weather data
truncated_weather_training_data = weather_training_data[weather_training_data["datetime"]>=start_date]

# %%
truncated_weather_training_data.shape
truncated_weather_length=len(truncated_weather_training_data)

# %%
truncated_weather_training_data["datetime"]
# Out:
# 14   2022-12-19
# 15   2022-12-20
# 16   2022-12-21
# 17   2022-12-22
# 18   2022-12-23
# 19   2022-12-24
# 20   2022-12-25
# 21   2022-12-26
# 22   2022-12-27
# 23   2022-12-28
# 24   2022-12-29
# 25   2022-12-30
# 26   2022-12-31
# 27   2023-01-01
# 28   2023-01-02
# 29   2023-01-03
# 30   2023-01-04
# 31   2023-01-05
# 32   2023-01-06
# 33   2023-01-07
# 34   2023-01-08
# 35   2023-01-09
# 36   2023-01-10
# 37   2023-01-11
# 38   2023-01-12
# 39   2023-01-13
# 40   2023-01-14
# Name: datetime, dtype: datetime64[ns]

# %%
col1 = aqi_training_data[:truncated_weather_length]

# %%
col1
# Out:
#      datetime  aqi
# 0  2022-12-17   29
# 1  2022-12-18   33
# 2  2022-12-19   29
# 3  2022-12-20   27
# 4  2022-12-21   31
# 5  2022-12-22   25
# 6  2022-12-23   44
# 7  2022-12-24   57
# 8  2022-12-25   45
# 9  2022-12-26   46
# 10 2022-12-27   51
# 11 2022-12-28   55
# 12 2022-12-29   60
# 13 2022-12-30   61
# 14 2022-12-31   57
# 15 2023-01-01   59
# 16 2023-01-02   60
# 17 2023-01-03   31
# 18 2023-01-04   26
# 19 2023-01-05   46
# 20 2023-01-06   46
# 21 2023-01-07   38
# 22 2023-01-08   41
# 23 2023-01-09   54
# 24 2023-01-10   72
# 25 2023-01-11   59
# 26 2023-01-12   57

# %%
truncated_weather_training_data["aqi"]=aqi_training_data["aqi"]
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9700\3101268457.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   truncated_weather_training_data["aqi"]=aqi_training_data["aqi"]

# %%
aqi_training_data["aqi"].shape
# Out:
# (30,)

# %%
truncated_weather_training_data.shape
# Out:
# (27, 37)

# %%
final=aqi_training_data.merge(weather_training_data,on="datetime", how="outer")
final=final.sort_values(by="datetime")

# %%
final["aqi_1"]=final["aqi"].shift(1)
final["aqi_2"]=final["aqi"].shift(2)
final["aqi_3"]=final["aqi"].shift(3)
final["aqi_4"]=final["aqi"].shift(4)
final["aqi_5"]=final["aqi"].shift(5)
final["aqi_6"]=final["aqi"].shift(6)
final["aqi_7"]=final["aqi"].shift(7)

# %%
final.tail()
# Out:
#      datetime   aqi  datetimeEpoch  tempmax  tempmin  temp  feelslikemax  \
# 25 2023-01-11  59.0   1.673366e+09     85.1     76.9  79.0          92.4
# 26 2023-01-12  57.0   1.673453e+09     90.4     75.3  81.9          98.1
# 27 2023-01-13  54.0   1.673539e+09     88.1     56.9  78.5          97.6
# 28 2023-01-14  65.0   1.673626e+09     87.6     48.7  78.1          96.7
# 29 2023-01-15  65.0            NaN      NaN      NaN   NaN           NaN
#
#     feelslikemin  feelslike   dew  ...  icon  \
# 25          76.9       80.3  73.9  ...  rain
# 26          75.3       85.6  72.8  ...  rain
# 27          56.9       80.6  73.5  ...  rain
# 28          48.7       80.9  72.8  ...  rain
# 29           NaN        NaN   NaN  ...   NaN
#
#                                              stations  source  aqi_1 aqi_2  \
# 25  ['48698099999', '48679099999', 'WSAP', '486940...     obs   72.0  54.0
# 26  ['48698099999', '48679099999', 'WSAP', '486940...     obs   59.0  72.0
# 27  ['48698099999', 'EUCDE37', '48679099999', 'WSA...     obs   57.0  59.0
# 28  ['EUCDE37', 'WSAP', 'WSSS', 'WIDD', 'WSSL', 'W...     obs   54.0  57.0
# 29                                                NaN     NaN   65.0  54.0
#
#     aqi_3  aqi_4  aqi_5  aqi_6  aqi_7
# 25   41.0   38.0   46.0   46.0   26.0
# 26   54.0   41.0   38.0   46.0   46.0
# 27   72.0   54.0   41.0   38.0   46.0
# 28   59.0   72.0   54.0   41.0   38.0
# 29   57.0   59.0   72.0   54.0   41.0
#
# [5 rows x 44 columns]

# %%
final=final.drop(["aqi"],axis=1)

# %%
final=final.dropna(subset=[f"aqi_{i}" for i in range(1,8)],how="any",axis="rows")

# %%
final=final.reset_index()

# %%
final=final.drop([len(final)-1],axis=0)

# %%
final.columns
# Out:
# Index(['index', 'datetime', 'datetimeEpoch', 'tempmax', 'tempmin', 'temp',
#        'feelslikemax', 'feelslikemin', 'feelslike', 'dew', 'humidity',
#        'precip', 'precipprob', 'precipcover', 'preciptype', 'snow',
#        'snowdepth', 'windgust', 'windspeed', 'winddir', 'pressure',
#        'cloudcover', 'visibility', 'solarradiation', 'solarenergy', 'uvindex',
#        'severerisk', 'sunrise', 'sunriseEpoch', 'sunset', 'sunsetEpoch',
#        'moonphase', 'conditions', 'description', 'icon', 'stations', 'source',
#        'aqi_1', 'aqi_2', 'aqi_3', 'aqi_4', 'aqi_5', 'aqi_6', 'aqi_7'],
#       dtype='object')

# %%
final.head(1)
# Out:
#    index   datetime  datetimeEpoch  tempmax  tempmin  temp  feelslikemax  \
# 0      7 2022-12-24   1.671811e+09     86.9     77.1  81.1          91.0
#
#    feelslikemin  feelslike   dew  ...               icon  \
# 0          77.1       83.0  71.3  ...  partly-cloudy-day
#
#                                             stations  source  aqi_1 aqi_2  \
# 0  ['48698099999', '48679099999', 'WSAP', '486940...     obs   44.0  25.0
#
#    aqi_3  aqi_4  aqi_5  aqi_6  aqi_7
# 0   31.0   27.0   29.0   33.0   29.0
#
# [1 rows x 44 columns]

# %%
columns_to_drop=["datetime","datetimeEpoch","preciptype","snowdepth","sunrise","sunset","icon","stations","source"]

# %%
final=final.drop(columns_to_drop,axis=1)

# %%
final.columns
# Out:
# Index(['index', 'tempmax', 'tempmin', 'temp', 'feelslikemax', 'feelslikemin',
#        'feelslike', 'dew', 'humidity', 'precip', 'precipprob', 'precipcover',
#        'snow', 'windgust', 'windspeed', 'winddir', 'pressure', 'cloudcover',
#        'visibility', 'solarradiation', 'solarenergy', 'uvindex', 'severerisk',
#        'sunriseEpoch', 'sunsetEpoch', 'moonphase', 'conditions', 'description',
#        'aqi_1', 'aqi_2', 'aqi_3', 'aqi_4', 'aqi_5', 'aqi_6', 'aqi_7'],
#       dtype='object')

# %%
weather_api="F5B6R3DHJAYYTDG9XVLMMHRBR"
latitude=1.3521
longitude=103.8198
locations=f"{latitude},{longitude}"
forcast_url=f"https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/weatherdata/forecast?locations={locations}&aggregateHours=24&unitGroup=us&shortColumnNames=false&contentType=json&key={weather_api}"

# %%
forcast_url
# Out:
# 'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/weatherdata/forecast?locations=1.3521,103.8198&aggregateHours=24&unitGroup=us&shortColumnNames=false&contentType=json&key=F5B6R3DHJAYYTDG9XVLMMHRBR'

# %%
import urllib
import json

# %%
print(' - Running query URL: ', forcast_url)
print()

try: 
    forcast_json = urllib.request.urlopen(forcast_url)
except urllib.error.HTTPError  as e:
    ErrorInfo= e.read().decode() 
    print('Error code: ', e.code, ErrorInfo)
    sys.exit()
except  urllib.error.URLError as e:
    ErrorInfo= e.read().decode() 
    print('Error code: ', e.code,ErrorInfo)
    sys.exit()
# Out:
#  - Running query URL:  https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/weatherdata/forecast?locations=1.3521,103.8198&aggregateHours=24&unitGroup=us&shortColumnNames=false&contentType=json&key=F5B6R3DHJAYYTDG9XVLMMHRBR

# %%
forcast_json = urllib.request.urlopen(forcast_url)

# %%
response = urllib.request.urlopen(forcast_url)

# %%
temp=response.read()

# %%
# Decode UTF-8 bytes to Unicode, and convert single quotes 
# to double quotes to make it valid JSON
my_json = temp.decode('utf8').replace("'", '"')
print(my_json)
print('- ' * 20)

# Load the JSON to a Python list & dump it back out as formatted JSON
data = json.loads(my_json)
s = json.dumps(data, indent=4, sort_keys=True)
print(s)
# Out:
# {"columns":{"wdir":{"id":"wdir","name":"Wind Direction","type":2,"unit":null},"uvindex":{"id":"uvindex","name":"weather_uvindex","type":2,"unit":null},"latitude":{"id":"latitude","name":"Latitude","type":2,"unit":null},"preciptype":{"id":"preciptype","name":"weather_preciptype","type":1,"unit":null},"cin":{"id":"cin","name":"weather_cin","type":2,"unit":null},"cloudcover":{"id":"cloudcover","name":"Cloud Cover","type":2,"unit":null},"pop":{"id":"pop","name":"Chance Precipitation (%)","type":2,"unit":null},"mint":{"id":"mint","name":"Minimum Temperature","type":2,"unit":"degF"},"datetime":{"id":"datetime","name":"Date time","type":3,"unit":null},"precip":{"id":"precip","name":"Precipitation","type":2,"unit":"in"},"solarradiation":{"id":"solarradiation","name":"Solar Radiation","type":2,"unit":null},"dew":{"id":"dew","name":"Dew Point","type":2,"unit":"degf"},"humidity":{"id":"humidity","name":"Relative Humidity","type":2,"unit":null},"longitude":{"id":"longitude","name":"Longitude","type":2,"unit":null},"temp":{"id":"temp","name":"Temperature","type":2,"unit":"degf"},"address":{"id":"address","name":"Address","type":1,"unit":null},"maxt":{"id":"maxt","name":"Maximum Temperature","type":2,"unit":"degF"},"visibility":{"id":"visibility","name":"Visibility","type":2,"unit":"mi"},"wspd":{"id":"wspd","name":"Wind Speed","type":2,"unit":"mph"},"severerisk":{"id":"severerisk","name":"weather_severerisk","type":2,"unit":null},"solarenergy":{"id":"solarenergy","name":"Solar Energy","type":2,"unit":null},"resolvedAddress":{"id":"resolvedAddress","name":"Resolved Address","type":1,"unit":null},"heatindex":{"id":"heatindex","name":"Heat Index","type":2,"unit":"degf"},"snowdepth":{"id":"snowdepth","name":"Snow Depth","type":2,"unit":"in"},"sealevelpressure":{"id":"sealevelpressure","name":"Sea Level Pressure","type":2,"unit":"mb"},"snow":{"id":"snow","name":"Snow","type":2,"unit":"in"},"name":{"id":"name","name":"Name","type":1,"unit":null},"wgust":{"id":"wgust","name":"Wind Gust","type":2,"unit":"mph"},"conditions":{"id":"conditions","name":"Conditions","type":1,"unit":null},"windchill":{"id":"windchill","name":"Wind Chill","type":2,"unit":"degf"},"cape":{"id":"cape","name":"weather_cape","type":2,"unit":null}},"remainingCost":0,"queryCost":1,"messages":null,"locations":{"1.3521,103.8198":{"stationContributions":null,"values":[{"wdir":294.6,"uvindex":3.0,"datetimeStr":"2023-01-15T00:00:00+08:00","preciptype":"","cin":-8.9,"cloudcover":99.4,"pop":90.5,"mint":80.5,"datetime":1673740800000,"precip":0.18,"solarradiation":311.8,"dew":73.2,"humidity":74.3,"temp":82.2,"maxt":83.0,"visibility":4.7,"wspd":8.1,"severerisk":28.0,"solarenergy":1.1,"heatindex":89.0,"snowdepth":null,"sealevelpressure":1007.8,"snow":null,"wgust":10.7,"conditions":"Rain, Overcast","windchill":null,"cape":1072.0},{"wdir":24.2,"uvindex":2.9,"datetimeStr":"2023-01-16T00:00:00+08:00","preciptype":"","cin":-10.3,"cloudcover":74.2,"pop":100.0,"mint":78.3,"datetime":1673827200000,"precip":0.74,"solarradiation":285.3,"dew":72.9,"humidity":77.4,"temp":80.7,"maxt":84.1,"visibility":2.7,"wspd":8.6,"severerisk":16.7,"solarenergy":1.0,"heatindex":89.4,"snowdepth":null,"sealevelpressure":1009.0,"snow":null,"wgust":19.7,"conditions":"Rain, Partially cloudy","windchill":null,"cape":808.7},{"wdir":14.7,"uvindex":2.3,"datetimeStr":"2023-01-17T00:00:00+08:00","preciptype":"","cin":-9.4,"cloudcover":88.9,"pop":85.7,"mint":76.7,"datetime":1673913600000,"precip":0.55,"solarradiation":231.7,"dew":72.6,"humidity":78.3,"temp":80.1,"maxt":83.9,"visibility":5.8,"wspd":11.1,"severerisk":10.8,"solarenergy":0.8,"heatindex":89.7,"snowdepth":null,"sealevelpressure":1010.0,"snow":null,"wgust":21.3,"conditions":"Rain, Overcast","windchill":null,"cape":639.0},{"wdir":17.0,"uvindex":2.6,"datetimeStr":"2023-01-18T00:00:00+08:00","preciptype":"","cin":-3.6,"cloudcover":88.0,"pop":71.4,"mint":76.9,"datetime":1674000000000,"precip":0.27,"solarradiation":263.3,"dew":72.7,"humidity":79.3,"temp":79.8,"maxt":83.4,"v ...
# - - - - - - - - - - - - - - - - - - - -
# {
#     "columns": {
#         "address": {
#             "id": "address",
#             "name": "Address",
#             "type": 1,
#             "unit": null
#         },
#         "cape": {
#             "id": "cape",
#             "name": "weather_cape",
#             "type": 2,
#             "unit": null
#         },
#         "cin": {
#             "id": "cin",
#             "name": "weather_cin",
#             "type": 2,
#             "unit": null
#         },
#         "cloudcover": {
#             "id": "cloudcover",
#             "name": "Cloud Cover",
#             "type": 2,
#             "unit": null
#         },
#         "conditions": {
#             "id": "conditions",
#             "name": "Conditions",
#             "type": 1,
#             "unit": null
#         },
#         "datetime": {
#             "id": "datetime",
#             "name": "Date time",
#             "type": 3,
#             "unit": null
#         },
#         "dew": {
#             "id": "dew",
#             "name": "Dew Point",
#             "type": 2,
#             "unit": "degf"
#         },
#         "heatindex": {
#             "id": "heatindex",
#             "name": "Heat Index",
#             "type": 2,
#             "unit": "degf"
#         },
#         "humidity": {
#             "id": "humidity",
#             "name": "Relative Humidity",
#             "type": 2,
#             "unit": null
#         },
#         "latitude": {
#             "id": "latitude",
#             "name": "Latitude",
#             "type": 2,
#             "unit": null
#         },
#         "longitude": {
#             "id": "longitude",
#             "name": "Longitude",
#             "type": 2,
#             "unit": null
#         },
#         "maxt": {
#             "id": "maxt",
#             "name": "Maximum Temperature",
#             "type": 2,
#             "unit": "degF"
#         },
#         "mint": {
#             "id": "mint",
#             "name": "Minimum Temperature",
#             "type": 2,
#             "unit": "degF"
#         },
#         "name": {
#             "id": "name",
#             "name": "Name",
#             "type": 1,
#             "unit": null
#         },
#         "pop": {
#             "id": "pop",
#             "name": "Chance Precipitation (%)",
#             "type": 2,
#             "unit": null
#         },
#         "precip": {
#             "id": "precip",
#             "name": "Precipitation",
#             "type": 2,
#             "unit": "in"
#         },
#         "preciptype": {
#             "id": "preciptype",
#             "name": "weather_preciptype",
#             "type": 1,
#             "unit": null
#         },
#         "resolvedAddress": {
#             "id": "resolvedAddress",
#             "name": "Resolved Address",
#             "type": 1,
#             "unit": null
#         },
#         "sealevelpressure": {
#             "id": "sealevelpressure",
#             "name": "Sea Level Pressure",
#             "type": 2,
#             "unit": "mb"
#         },
#         "severerisk": {
#             "id": "severerisk",
#             "name": "weather_severerisk",
#             "type": 2,
#             "unit": null
#         },
#         "snow": {
#             "id": "snow",
#             "name": "Snow",
#             "type": 2,
#             "unit": "in"
#         },
#         "snowdepth": {
#             "id": "snowdepth",
#             "name": "Snow Depth",
#             "type": 2,
#             "unit": "in"
#         },
#         "solarenergy": {
#             "id": "solarenergy",
#             "name": "Solar Energy",
#             "type": 2,
#             "unit": null
#         },
#         "solarradiation": {
#             "id": "solarradiation",
#             "name": "Solar Radiation",
#             "type": 2,
#             "unit": null
#         },
#         "temp": {
#             "id": "temp",
#             "name": "Temperature",
#             "type": 2,
#             "unit": "degf"
#         },
#         "uvindex": {
#             "id": "uvindex",
#             "name": "weather_uvindex",
#             "type": 2,
#             "unit": null
#         },
#         "visibility": {
#             "id": "visibility",
#             "name": "Visibility",
#             "type": 2,
#             "unit": "mi"
#         },
#         "wdir": {
#             "id": "wdir",
#             "name": "Wind Direction",
#             "type": 2,
#             "unit": null
#         },
#         "wgust": {
#             "id": "wgust",
#             "name": "Wind Gust",
#             "type": 2,
#             "unit": "mph"
#         },
#         "windchill": {
#             "id": "windchill",
#             "name": "Wind Chill",
#             "type": 2,
#             "unit": "degf"
#         },
#         "wspd": {
#             "id": "wspd",
#             "name": "Wind Speed",
#             "type": 2,
#             "unit": "mph"
#         }
#     },
#     "locations": {
#         "1.3521,103.8198": {
#             "address": "1.3521,103.8198",
#             "alerts": null,
#             "currentConditions": {},
#             "distance": 0.0,
#             "id": "1.3521,103.8198",
#             "index": 0,
#             "latitude": 1.3521,
#             "longitude": 103.8198,
#             "name": "1.3521,103.8198",
#             "stationContributions": null,
#             "time": 0.0,
#             "tz": "Asia/Singapore",
#             "values": [
#                 {
#                     "cape": 1072.0,
#                     "cin": -8.9,
#                     "cloudcover": 99.4,
#                     "conditions": "Rain, Overcast",
#                     "datetime": 1673740800000,
#                     "datetimeStr": "2023-01-15T00:00:00+08:00",
#                     "dew": 73.2,
#                     "heatindex": 89.0,
#                     "humidity": 74.3,
#                     "maxt": 83.0,
#                     "mint": 80.5,
#                     "pop": 90.5,
#                     "precip": 0.18,
#                     "preciptype": "",
#                     "sealevelpressure": 1007.8,
#                     "severerisk": 28.0,
#                     "snow": null,
#                     "snowdepth": null,
#                     "solarenergy": 1.1,
#                     "solarradiation": 311.8,
#                     "temp": 82.2,
#                     "uvindex": 3.0,
#                     "visibility": 4.7,
#                     "wdir": 294.6,
#                     "wgust": 10.7,
#                     "windchill": null,
#                     "wspd": 8.1
#                 },
#                 {
#                     "cape": 808.7,
#                     "cin": -10.3,
#                     "cloudcover": 74.2,
#                     "conditions": "Rain, Partially cloudy",
#                     "datetime": 1673827200000,
#                     "datetimeStr": "2023-01-16T00:00:00+08:00",
#                     "dew": 72.9,
#                     "heatindex": 89.4,
#                     "humidity": 77.4,
#                     "maxt": 84.1,
#                     "mint": 78.3,
#                     "pop": 100.0,
#                     "precip": 0.74,
#                     "preciptype": "",
#                     "sealevelpressure": 1009.0,
#                     "severerisk": 16.7,
#                     "snow": null,
#                     "snowdepth": null,
#                     "solarenergy": 1.0,
#                     "solarradiation": 285.3,
#                     "temp": 80.7,
#                     "uvindex": 2.9,
#                     "visibility": 2.7,
#                     "wdir": 24.2,
#                     "wgust": 19.7,
#                     "windchill": null,
#                     "wspd": 8.6
#                 },
#                 {
#                     "cape": 639.0,
#                     "cin": -9.4,
#                     "cloudcover": 88.9,
#                     "conditions": "Rain, Overcast",
#                     "datetime": 1673913600000,
#                     "datetimeStr": "2023-01-17T00:00:00+08:00",
#                     "dew": 72.6,
#                     "heatindex": 89.7,
#                     "humidity": 78.3,
#                     "maxt": 83.9,
#                     "mint": 76.7,
#                     "pop": 85.7,
#                     "precip": 0.55,
#                     "preciptype": "",
#                     "sealevelpressure": 1010.0,
#                     "severerisk": 10.8,
#                     "snow": null,
#                     "snowdepth": null,
#                     "solarenergy": 0.8,
#                     "solarradiation": 231.7,
#                     "temp": 80.1,
#                     "uvindex": 2.3,
#                     "visibility": 5.8,
#                     "wdir": 14.7,
#                     "wgust": 21.3,
#                     "windchill": null,
#                     "wspd": 11.1
#                 },
#                 {
#                     "cape": 572.6,
#                     "cin": -3.6,
#                     "cloudcover": 88.0,
#                     "conditions": "Rain, Overcast",
#                     "datetime": 1674000000000,
#                     "datetimeStr": "2023-01-18T00:00:00+08:00",
#                     "dew": 72.7,
#                     "heatindex": 89.1,
#                     "humidity": 79.3,
#                     "maxt": 83.4,
#                     "mint": 76.9,
#                     "pop": 71.4,
#                     "precip": 0.27,
#                     "preciptype": "",
#                     "sealevelpressure": 1010.3,
#                     "severerisk": 10.0,
#                     "snow": null,
#                     "snowdepth": null,
#                     "solarenergy": 0.9,
#                     "solarradiation": 263.3,
#                     "temp": 79.8,
#                     "uvindex": 2.6,
#                     "visibility": 6.7,
#                     "wdir": 17.0,
#                     "wgust": 19.9,
#                     "windchill": null,
#                     "wspd": 12.4
#                 },
#                 {
#                     "cape": 705.1,
#                     "cin": -6.1,
#                     "cloudcover": 93.9,
#                     "conditions": "Rain, Overcast",
#                     "datetime": 1674086400000,
#                     "datetimeStr": "2023-01-19T00:00:00+08:00",
#                     "dew": 72.7,
#                     "heatindex": 89.1,
#                     "humidity": 79.2,
#                     "maxt": 83.6,
#                     "mint": 77.1,
#                     "pop": 57.1,
#                     "precip": 0.24,
#                     "preciptype": "",
#                     "sealevelpressure": 1009.5,
#                     "severerisk": 13.3,
#                     "snow": null,
#                     "snowdepth": null,
#                     "solarenergy": 0.5,
#                     "solarradiation": 125.8,
#                     "temp": 79.9,
#                     "uvindex": 1.3,
#                     "visibility": 5.3,
#                     "wdir": 40.7,
#                     "wgust": 21.3,
#                     "windchill": null,
#                     "wspd": 10.6
#                 },
#                 {
#                     "cape": 855.7,
#                     "cin": -15.7,
#                     "cloudcover": 100.0,
#                     "conditions": "Rain, Overcast",
#                     "datetime": 1674172800000,
#                     "datetimeStr": "2023-01-20T00:00:00+08:00",
#                     "dew": 73.3,
#                     "heatindex": 85.8,
#                     "humidity": 83.2,
#                     "maxt": 81.1,
#                     "mint": 76.7,
#                     "pop": 85.7,
#                     "precip": 0.85,
#                     "preciptype": "",
#                     "sealevelpressure": 1008.9,
#                     "severerisk": 20.0,
#                     "snow": 0.0,
#                     "snowdepth": null,
#                     "solarenergy": 0.4,
#                     "solarradiation": 116.1,
#                     "temp": 78.9,
#                     "uvindex": 1.2,
#                     "visibility": 4.0,
#                     "wdir": 89.3,
#                     "wgust": 21.7,
#                     "windchill": null,
#                     "wspd": 10.6
#                 },
#                 {
#                     "cape": 630.4,
#                     "cin": -5.5,
#                     "cloudcover": 62.0,
#                     "conditions": "Rain, Partially cloudy",
#                     "datetime": 1674259200000,
#                     "datetimeStr": "2023-01-21T00:00:00+08:00",
#                     "dew": 72.4,
#                     "heatindex": 87.6,
#                     "humidity": 78.7,
#                     "maxt": 83.2,
#                     "mint": 77.4,
#                     "pop": 90.5,
#                     "precip": 0.48,
#                     "preciptype": "",
#                     "sealevelpressure": 1007.8,
#                     "severerisk": 10.8,
#                     "snow": 0.0,
#                     "snowdepth": null,
#                     "solarenergy": 0.9,
#                     "solarradiation": 263.5,
#                     "temp": 79.7,
#                     "uvindex": 2.7,
#                     "visibility": 4.1,
#                     "wdir": 157.9,
#                     "wgust": 14.3,
#                     "windchill": null,
#                     "wspd": 7.1
#                 },
#                 {
#                     "cape": 618.0,
#                     "cin": -11.2,
#                     "cloudcover": 83.5,
#                     "conditions": "Rain, Overcast",
#                     "datetime": 1674345600000,
#                     "datetimeStr": "2023-01-22T00:00:00+08:00",
#                     "dew": 72.8,
#                     "heatindex": 87.5,
#                     "humidity": 80.3,
#                     "maxt": 82.7,
#                     "mint": 76.9,
#                     "pop": 100.0,
#                     "precip": 0.46,
#                     "preciptype": "",
#                     "sealevelpressure": 1007.5,
#                     "severerisk": 10.0,
#                     "snow": 0.0,
#                     "snowdepth": null,
#                     "solarenergy": 0.9,
#                     "solarradiation": 249.3,
#                     "temp": 79.5,
#                     "uvindex": 2.5,
#                     "visibility": 3.8,
#                     "wdir": 185.8,
#                     "wgust": 13.6,
#                     "windchill": null,
#                     "wspd": 6.9
#                 },
#                 {
#                     "cape": 704.7,
#                     "cin": -7.2,
#                     "cloudcover": 90.9,
#                     "conditions": "Rain, Overcast",
#                     "datetime": 1674432000000,
#                     "datetimeStr": "2023-01-23T00:00:00+08:00",
#                     "dew": 73.2,
#                     "heatindex": 88.3,
#                     "humidity": 80.6,
#                     "maxt": 82.8,
#                     "mint": 77.4,
#                     "pop": 90.5,
#                     "precip": 0.68,
#                     "preciptype": "",
#                     "sealevelpressure": 1007.6,
#                     "severerisk": 10.8,
#                     "snow": 0.0,
#                     "snowdepth": null,
#                     "solarenergy": 0.9,
#                     "solarradiation": 256.1,
#                     "temp": 79.8,
#                     "uvindex": 2.5,
#                     "visibility": 3.7,
#                     "wdir": 21.8,
#                     "wgust": 18.1,
#                     "windchill": null,
#                     "wspd": 9.9
#                 },
#                 {
#                     "cape": 428.0,
#                     "cin": -10.0,
#                     "cloudcover": 87.5,
#                     "conditions": "Rain, Overcast",
#                     "datetime": 1674518400000,
#                     "datetimeStr": "2023-01-24T00:00:00+08:00",
#                     "dew": 72.9,
#                     "heatindex": 85.7,
#                     "humidity": 83.0,
#                     "maxt": 80.9,
#                     "mint": 77.4,
#                     "pop": 95.2,
#                     "precip": 0.25,
#                     "preciptype": "",
#                     "sealevelpressure": 1007.9,
#                     "severerisk": 10.0,
#                     "snow": 0.0,
#                     "snowdepth": null,
#                     "solarenergy": 0.8,
#                     "solarradiation": 222.3,
#                     "temp": 78.5,
#                     "uvindex": 2.2,
#                     "visibility": 7.3,
#                     "wdir": 15.7,
#                     "wgust": 17.7,
#                     "windchill": null,
#                     "wspd": 11.9
#                 },
#                 {
#                     "cape": 459.2,
#                     "cin": -8.4,
#                     "cloudcover": 78.7,
#                     "conditions": "Rain, Overcast",
#                     "datetime": 1674604800000,
#                     "datetimeStr": "2023-01-25T00:00:00+08:00",
#                     "dew": 72.9,
#                     "heatindex": 86.1,
#                     "humidity": 82.3,
#                     "maxt": 81.2,
#                     "mint": 76.6,
#                     "pop": 90.5,
#                     "precip": 0.74,
#                     "preciptype": "",
#                     "sealevelpressure": 1007.2,
#                     "severerisk": 10.0,
#                     "snow": 0.0,
#                     "snowdepth": null,
#                     "solarenergy": 0.9,
#                     "solarradiation": 254.0,
#                     "temp": 78.8,
#                     "uvindex": 2.6,
#                     "visibility": 3.7,
#                     "wdir": 217.9,
#                     "wgust": 21.7,
#                     "windchill": null,
#                     "wspd": 10.7
#                 },
#                 {
#                     "cape": 859.9,
#                     "cin": -14.8,
#                     "cloudcover": 94.8,
#                     "conditions": "Rain, Overcast",
#                     "datetime": 1674691200000,
#                     "datetimeStr": "2023-01-26T00:00:00+08:00",
#                     "dew": 73.9,
#                     "heatindex": 89.1,
#                     "humidity": 82.5,
#                     "maxt": 82.7,
#                     "mint": 76.7,
#                     "pop": 85.7,
#                     "precip": 0.64,
#                     "preciptype": "",
#                     "sealevelpressure": 1007.2,
#                     "severerisk": 20.8,
#                     "snow": 0.0,
#                     "snowdepth": null,
#                     "solarenergy": 0.5,
#                     "solarradiation": 144.6,
#                     "temp": 79.8,
#                     "uvindex": 1.4,
#                     "visibility": 4.8,
#                     "wdir": 301.1,
#                     "wgust": 20.1,
#                     "windchill": null,
#                     "wspd": 13.1
#                 },
#                 {
#                     "cape": 644.5,
#                     "cin": -17.1,
#                     "cloudcover": 89.4,
#                     "conditions": "Rain, Overcast",
#                     "datetime": 1674777600000,
#                     "datetimeStr": "2023-01-27T00:00:00+08:00",
#                     "dew": 72.7,
#                     "heatindex": 87.6,
#                     "humidity": 78.3,
#                     "maxt": 82.3,
#                     "mint": 78.7,
#                     "pop": 66.7,
#                     "precip": 0.31,
#                     "preciptype": "",
#                     "sealevelpressure": 1008.1,
#                     "severerisk": 11.7,
#                     "snow": 0.0,
#                     "snowdepth": null,
#                     "solarenergy": 0.5,
#                     "solarradiation": 126.3,
#                     "temp": 80.2,
#                     "uvindex": 1.3,
#                     "visibility": 5.7,
#                     "wdir": 239.3,
#                     "wgust": 20.8,
#                     "windchill": null,
#                     "wspd": 8.4
#                 },
#                 {
#                     "cape": 555.1,
#                     "cin": -19.8,
#                     "cloudcover": 74.5,
#                     "conditions": "Rain, Partially cloudy",
#                     "datetime": 1674864000000,
#                     "datetimeStr": "2023-01-28T00:00:00+08:00",
#                     "dew": 72.8,
#                     "heatindex": 87.4,
#                     "humidity": 78.7,
#                     "maxt": 82.3,
#                     "mint": 77.6,
#                     "pop": 66.7,
#                     "precip": 0.17,
#                     "preciptype": "",
#                     "sealevelpressure": 1007.2,
#                     "severerisk": 10.0,
#                     "snow": 0.0,
#                     "snowdepth": null,
#                     "solarenergy": 1.0,
#                     "solarradiation": 289.9,
#                     "temp": 80.1,
#                     "uvindex": 3.0,
#                     "visibility": 13.2,
#                     "wdir": 117.5,
#                     "wgust": 10.1,
#                     "windchill": null,
#                     "wspd": 6.3
#                 },
#                 {
#                     "cape": 642.1,
#                     "cin": -12.2,
#                     "cloudcover": 95.4,
#                     "conditions": "Rain, Overcast",
#                     "datetime": 1674950400000,
#                     "datetimeStr": "2023-01-29T00:00:00+08:00",
#                     "dew": 73.6,
#                     "heatindex": 87.9,
#                     "humidity": 80.5,
#                     "maxt": 82.1,
#                     "mint": 78.2,
#                     "pop": 66.7,
#                     "precip": 0.48,
#                     "preciptype": "",
#                     "sealevelpressure": 1006.4,
#                     "severerisk": 12.5,
#                     "snow": 0.0,
#                     "snowdepth": null,
#                     "solarenergy": 0.9,
#                     "solarradiation": 249.5,
#                     "temp": 80.1,
#                     "uvindex": 2.5,
#                     "visibility": 5.2,
#                     "wdir": 172.3,
#                     "wgust": 18.1,
#                     "windchill": null,
#                     "wspd": 9.2
#                 },
#                 {
#                     "cape": 729.3,
#                     "cin": -15.0,
#                     "cloudcover": 93.1,
#                     "conditions": "Rain, Overcast",
#                     "datetime": 1675036800000,
#                     "datetimeStr": "2023-01-30T00:00:00+08:00",
#                     "dew": 73.7,
#                     "heatindex": 90.2,
#                     "humidity": 79.3,
#                     "maxt": 83.7,
#                     "mint": 78.5,
#                     "pop": 57.1,
#                     "precip": 0.89,
#                     "preciptype": "",
#                     "sealevelpressure": 1006.2,
#                     "severerisk": 10.0,
#                     "snow": 0.0,
#                     "snowdepth": null,
#                     "solarenergy": 0.9,
#                     "solarradiation": 241.3,
#                     "temp": 80.8,
#                     "uvindex": 2.3,
#                     "visibility": 5.0,
#                     "wdir": 312.4,
#                     "wgust": 23.0,
#                     "windchill": null,
#                     "wspd": 11.5
#                 }
#             ]
#         }
#     },
#     "messages": null,
#     "queryCost": 1,
#     "remainingCost": 0
# }

# %%
ans=json.loads(forcast_json.read())

# %%
forcast_json.read()
# Out:
# b''

# %%
ans
# Out:
# {'columns': {'wdir': {'id': 'wdir',
#    'name': 'Wind Direction',
#    'type': 2,
#    'unit': None},
#   'uvindex': {'id': 'uvindex',
#    'name': 'weather_uvindex',
#    'type': 2,
#    'unit': None},
#   'latitude': {'id': 'latitude', 'name': 'Latitude', 'type': 2, 'unit': None},
#   'preciptype': {'id': 'preciptype',
#    'name': 'weather_preciptype',
#    'type': 1,
#    'unit': None},
#   'cin': {'id': 'cin', 'name': 'weather_cin', 'type': 2, 'unit': None},
#   'cloudcover': {'id': 'cloudcover',
#    'name': 'Cloud Cover',
#    'type': 2,
#    'unit': None},
#   'pop': {'id': 'pop',
#    'name': 'Chance Precipitation (%)',
#    'type': 2,
#    'unit': None},
#   'mint': {'id': 'mint',
#    'name': 'Minimum Temperature',
#    'type': 2,
#    'unit': 'degF'},
#   'datetime': {'id': 'datetime', 'name': 'Date time', 'type': 3, 'unit': None},
#   'precip': {'id': 'precip', 'name': 'Precipitation', 'type': 2, 'unit': 'in'},
#   'solarradiation': {'id': 'solarradiation',
#    'name': 'Solar Radiation',
#    'type': 2,
#    'unit': None},
#   'dew': {'id': 'dew', 'name': 'Dew Point', 'type': 2, 'unit': 'degf'},
#   'humidity': {'id': 'humidity',
#    'name': 'Relative Humidity',
#    'type': 2,
#    'unit': None},
#   'longitude': {'id': 'longitude',
#    'name': 'Longitude',
#    'type': 2,
#    'unit': None},
#   'temp': {'id': 'temp', 'name': 'Temperature', 'type': 2, 'unit': 'degf'},
#   'address': {'id': 'address', 'name': 'Address', 'type': 1, 'unit': None},
#   'maxt': {'id': 'maxt',
#    'name': 'Maximum Temperature',
#    'type': 2,
#    'unit': 'degF'},
#   'visibility': {'id': 'visibility',
#    'name': 'Visibility',
#    'type': 2,
#    'unit': 'mi'},
#   'wspd': {'id': 'wspd', 'name': 'Wind Speed', 'type': 2, 'unit': 'mph'},
#   'severerisk': {'id': 'severerisk',
#    'name': 'weather_severerisk',
#    'type': 2,
#    'unit': None},
#   'solarenergy': {'id': 'solarenergy',
#    'name': 'Solar Energy',
#    'type': 2,
#    'unit': None},
#   'resolvedAddress': {'id': 'resolvedAddress',
#    'name': 'Resolved Address',
#    'type': 1,
#    'unit': None},
#   'heatindex': {'id': 'heatindex',
#    'name': 'Heat Index',
#    'type': 2,
#    'unit': 'degf'},
#   'snowdepth': {'id': 'snowdepth',
#    'name': 'Snow Depth',
#    'type': 2,
#    'unit': 'in'},
#   'sealevelpressure': {'id': 'sealevelpressure',
#    'name': 'Sea Level Pressure',
#    'type': 2,
#    'unit': 'mb'},
#   'snow': {'id': 'snow', 'name': 'Snow', 'type': 2, 'unit': 'in'},
#   'name': {'id': 'name', 'name': 'Name', 'type': 1, 'unit': None},
#   'wgust': {'id': 'wgust', 'name': 'Wind Gust', 'type': 2, 'unit': 'mph'},
#   'conditions': {'id': 'conditions',
#    'name': 'Conditions',
#    'type': 1,
#    'unit': None},
#   'windchill': {'id': 'windchill',
#    'name': 'Wind Chill',
#    'type': 2,
#    'unit': 'degf'},
#   'cape': {'id': 'cape', 'name': 'weather_cape', 'type': 2, 'unit': None}},
#  'remainingCost': 0,
#  'queryCost': 1,
#  'messages': None,
#  'locations': {'1.3521,103.8198': {'stationContributions': None,
#    'values': [{'wdir': 294.6,
#      'uvindex': 3.0,
#      'datetimeStr': '2023-01-15T00:00:00+08:00',
#      'preciptype': '',
#      'cin': -8.9,
#      'cloudcover': 99.4,
#      'pop': 90.5,
#      'mint': 80.5,
#      'datetime': 1673740800000,
#      'precip': 0.18,
#      'solarradiation': 311.8,
#      'dew': 73.2,
#      'humidity': 74.3,
#      'temp': 82.2,
#      'maxt': 83.0,
#      'visibility': 4.7,
#      'wspd': 8.1,
#      'severerisk': 28.0,
#      'solarenergy': 1.1,
#      'heatindex': 89.0,
#      'snowdepth': None,
#      'sealevelpressure': 1007.8,
#      'snow': None,
#      'wgust': 10.7,
#      'conditions': 'Rain, Overcast',
#      'windchill': None,
#      'cape': 1072.0},
#     {'wdir': 24.2,
#      'uvindex': 2.9,
#      'datetimeStr': '2023-01-16T00:00:00+08:00',
#      'preciptype': '',
#      'cin': -10.3,
#      'cloudcover': 74.2,
#      'pop': 100.0,
#      'mint': 78.3,
#      'datetime': 1673827200000,
#      'precip': 0.74,
#      'solarradiation': 285.3,
#      'dew': 72.9,
#      'humidity': 77.4,
#      'temp': 80.7,
#      'maxt': 84.1,
#      'visibility': 2.7,
#      'wspd': 8.6,
#      'severerisk': 16.7,
#      'solarenergy': 1.0,
#      'heatindex': 89.4,
#      'snowdepth': None,
#      'sealevelpressure': 1009.0,
#      'snow': None,
#      'wgust': 19.7,
#      'conditions': 'Rain, Partially cloudy',
#      'windchill': None,
#      'cape': 808.7},
#     {'wdir': 14.7,
#      'uvindex': 2.3,
#      'datetimeStr': '2023-01-17T00:00:00+08:00',
#      'preciptype': '',
#      'cin': -9.4,
#      'cloudcover': 88.9,
#      'pop': 85.7,
#      'mint': 76.7,
#      'datetime': 1673913600000,
#      'precip': 0.55,
#      'solarradiation': 231.7,
#      'dew': 72.6,
#      'humidity': 78.3,
#      'temp': 80.1,
#      'maxt': 83.9,
#      'visibility': 5.8,
#      'wspd': 11.1,
#      'severerisk': 10.8,
#      'solarenergy': 0.8,
#      'heatindex': 89.7,
#      'snowdepth': None,
#      'sealevelpressure': 1010.0,
#      'snow': None,
#      'wgust': 21.3,
#      'conditions': 'Rain, Overcast',
#      'windchill': None,
#      'cape': 639.0},
#     {'wdir': 17.0,
#      'uvindex': 2.6,
#      'datetimeStr': '2023-01-18T00:00:00+08:00',
#      'preciptype': '',
#      'cin': -3.6,
#      'cloudcover': 88.0,
#      'pop': 71.4,
#      'mint': 76.9,
#      'datetime': 1674000000000,
#      'precip': 0.27,
#      'solarradiation': 263.3,
#      'dew': 72.7,
#      'humidity': 79.3,
#      'temp': 79.8,
#      'maxt': 83.4,
#      'visibility': 6.7,
#      'wspd': 12.4,
#      'severerisk': 10.0,
#      'solarenergy': 0.9,
#      'heatindex': 89.1,
#      'snowdepth': None,
#      'sealevelpressure': 1010.3,
#      'snow': None,
#      'wgust': 19.9,
#      'conditions': 'Rain, Overcast',
#      'windchill': None,
#      'cape': 572.6},
#     {'wdir': 40.7,
#      'uvindex': 1.3,
#      'datetimeStr': '2023-01-19T00:00:00+08:00',
#      'preciptype': '',
#      'cin': -6.1,
#      'cloudcover': 93.9,
#      'pop': 57.1,
#      'mint': 77.1,
#      'datetime': 1674086400000,
#      'precip': 0.24,
#      'solarradiation': 125.8,
#      'dew': 72.7,
#      'humidity': 79.2,
#      'temp': 79.9,
#      'maxt': 83.6,
#      'visibility': 5.3,
#      'wspd': 10.6,
#      'severerisk': 13.3,
#      'solarenergy': 0.5,
#      'heatindex': 89.1,
#      'snowdepth': None,
#      'sealevelpressure': 1009.5,
#      'snow': None,
#      'wgust': 21.3,
#      'conditions': 'Rain, Overcast',
#      'windchill': None,
#      'cape': 705.1},
#     {'wdir': 89.3,
#      'uvindex': 1.2,
#      'datetimeStr': '2023-01-20T00:00:00+08:00',
#      'preciptype': '',
#      'cin': -15.7,
#      'cloudcover': 100.0,
#      'pop': 85.7,
#      'mint': 76.7,
#      'datetime': 1674172800000,
#      'precip': 0.85,
#      'solarradiation': 116.1,
#      'dew': 73.3,
#      'humidity': 83.2,
#      'temp': 78.9,
#      'maxt': 81.1,
#      'visibility': 4.0,
#      'wspd': 10.6,
#      'severerisk': 20.0,
#      'solarenergy': 0.4,
#      'heatindex': 85.8,
#      'snowdepth': None,
#      'sealevelpressure': 1008.9,
#      'snow': 0.0,
#      'wgust': 21.7,
#      'conditions': 'Rain, Overcast',
#      'windchill': None,
#      'cape': 855.7},
#     {'wdir': 157.9,
#      'uvindex': 2.7,
#      'datetimeStr': '2023-01-21T00:00:00+08:00',
#      'preciptype': '',
#      'cin': -5.5,
#      'cloudcover': 62.0,
#      'pop': 90.5,
#      'mint': 77.4,
#      'datetime': 1674259200000,
#      'precip': 0.48,
#      'solarradiation': 263.5,
#      'dew': 72.4,
#      'humidity': 78.7,
#      'temp': 79.7,
#      'maxt': 83.2,
#      'visibility': 4.1,
#      'wspd': 7.1,
#      'severerisk': 10.8,
#      'solarenergy': 0.9,
#      'heatindex': 87.6,
#      'snowdepth': None,
#      'sealevelpressure': 1007.8,
#      'snow': 0.0,
#      'wgust': 14.3,
#      'conditions': 'Rain, Partially cloudy',
#      'windchill': None,
#      'cape': 630.4},
#     {'wdir': 185.8,
#      'uvindex': 2.5,
#      'datetimeStr': '2023-01-22T00:00:00+08:00',
#      'preciptype': '',
#      'cin': -11.2,
#      'cloudcover': 83.5,
#      'pop': 100.0,
#      'mint': 76.9,
#      'datetime': 1674345600000,
#      'precip': 0.46,
#      'solarradiation': 249.3,
#      'dew': 72.8,
#      'humidity': 80.3,
#      'temp': 79.5,
#      'maxt': 82.7,
#      'visibility': 3.8,
#      'wspd': 6.9,
#      'severerisk': 10.0,
#      'solarenergy': 0.9,
#      'heatindex': 87.5,
#      'snowdepth': None,
#      'sealevelpressure': 1007.5,
#      'snow': 0.0,
#      'wgust': 13.6,
#      'conditions': 'Rain, Overcast',
#      'windchill': None,
#      'cape': 618.0},
#     {'wdir': 21.8,
#      'uvindex': 2.5,
#      'datetimeStr': '2023-01-23T00:00:00+08:00',
#      'preciptype': '',
#      'cin': -7.2,
#      'cloudcover': 90.9,
#      'pop': 90.5,
#      'mint': 77.4,
#      'datetime': 1674432000000,
#      'precip': 0.68,
#      'solarradiation': 256.1,
#      'dew': 73.2,
#      'humidity': 80.6,
#      'temp': 79.8,
#      'maxt': 82.8,
#      'visibility': 3.7,
#      'wspd': 9.9,
#      'severerisk': 10.8,
#      'solarenergy': 0.9,
#      'heatindex': 88.3,
#      'snowdepth': None,
#      'sealevelpressure': 1007.6,
#      'snow': 0.0,
#      'wgust': 18.1,
#      'conditions': 'Rain, Overcast',
#      'windchill': None,
#      'cape': 704.7},
#     {'wdir': 15.7,
#      'uvindex': 2.2,
#      'datetimeStr': '2023-01-24T00:00:00+08:00',
#      'preciptype': '',
#      'cin': -10.0,
#      'cloudcover': 87.5,
#      'pop': 95.2,
#      'mint': 77.4,
#      'datetime': 1674518400000,
#      'precip': 0.25,
#      'solarradiation': 222.3,
#      'dew': 72.9,
#      'humidity': 83.0,
#      'temp': 78.5,
#      'maxt': 80.9,
#      'visibility': 7.3,
#      'wspd': 11.9,
#      'severerisk': 10.0,
#      'solarenergy': 0.8,
#      'heatindex': 85.7,
#      'snowdepth': None,
#      'sealevelpressure': 1007.9,
#      'snow': 0.0,
#      'wgust': 17.7,
#      'conditions': 'Rain, Overcast',
#      'windchill': None,
#      'cape': 428.0},
#     {'wdir': 217.9,
#      'uvindex': 2.6,
#      'datetimeStr': '2023-01-25T00:00:00+08:00',
#      'preciptype': '',
#      'cin': -8.4,
#      'cloudcover': 78.7,
#      'pop': 90.5,
#      'mint': 76.6,
#      'datetime': 1674604800000,
#      'precip': 0.74,
#      'solarradiation': 254.0,
#      'dew': 72.9,
#      'humidity': 82.3,
#      'temp': 78.8,
#      'maxt': 81.2,
#      'visibility': 3.7,
#      'wspd': 10.7,
#      'severerisk': 10.0,
#      'solarenergy': 0.9,
#      'heatindex': 86.1,
#      'snowdepth': None,
#      'sealevelpressure': 1007.2,
#      'snow': 0.0,
#      'wgust': 21.7,
#      'conditions': 'Rain, Overcast',
#      'windchill': None,
#      'cape': 459.2},
#     {'wdir': 301.1,
#      'uvindex': 1.4,
#      'datetimeStr': '2023-01-26T00:00:00+08:00',
#      'preciptype': '',
#      'cin': -14.8,
#      'cloudcover': 94.8,
#      'pop': 85.7,
#      'mint': 76.7,
#      'datetime': 1674691200000,
#      'precip': 0.64,
#      'solarradiation': 144.6,
#      'dew': 73.9,
#      'humidity': 82.5,
#      'temp': 79.8,
#      'maxt': 82.7,
#      'visibility': 4.8,
#      'wspd': 13.1,
#      'severerisk': 20.8,
#      'solarenergy': 0.5,
#      'heatindex': 89.1,
#      'snowdepth': None,
#      'sealevelpressure': 1007.2,
#      'snow': 0.0,
#      'wgust': 20.1,
#      'conditions': 'Rain, Overcast',
#      'windchill': None,
#      'cape': 859.9},
#     {'wdir': 239.3,
#      'uvindex': 1.3,
#      'datetimeStr': '2023-01-27T00:00:00+08:00',
#      'preciptype': '',
#      'cin': -17.1,
#      'cloudcover': 89.4,
#      'pop': 66.7,
#      'mint': 78.7,
#      'datetime': 1674777600000,
#      'precip': 0.31,
#      'solarradiation': 126.3,
#      'dew': 72.7,
#      'humidity': 78.3,
#      'temp': 80.2,
#      'maxt': 82.3,
#      'visibility': 5.7,
#      'wspd': 8.4,
#      'severerisk': 11.7,
#      'solarenergy': 0.5,
#      'heatindex': 87.6,
#      'snowdepth': None,
#      'sealevelpressure': 1008.1,
#      'snow': 0.0,
#      'wgust': 20.8,
#      'conditions': 'Rain, Overcast',
#      'windchill': None,
#      'cape': 644.5},
#     {'wdir': 117.5,
#      'uvindex': 3.0,
#      'datetimeStr': '2023-01-28T00:00:00+08:00',
#      'preciptype': '',
#      'cin': -19.8,
#      'cloudcover': 74.5,
#      'pop': 66.7,
#      'mint': 77.6,
#      'datetime': 1674864000000,
#      'precip': 0.17,
#      'solarradiation': 289.9,
#      'dew': 72.8,
#      'humidity': 78.7,
#      'temp': 80.1,
#      'maxt': 82.3,
#      'visibility': 13.2,
#      'wspd': 6.3,
#      'severerisk': 10.0,
#      'solarenergy': 1.0,
#      'heatindex': 87.4,
#      'snowdepth': None,
#      'sealevelpressure': 1007.2,
#      'snow': 0.0,
#      'wgust': 10.1,
#      'conditions': 'Rain, Partially cloudy',
#      'windchill': None,
#      'cape': 555.1},
#     {'wdir': 172.3,
#      'uvindex': 2.5,
#      'datetimeStr': '2023-01-29T00:00:00+08:00',
#      'preciptype': '',
#      'cin': -12.2,
#      'cloudcover': 95.4,
#      'pop': 66.7,
#      'mint': 78.2,
#      'datetime': 1674950400000,
#      'precip': 0.48,
#      'solarradiation': 249.5,
#      'dew': 73.6,
#      'humidity': 80.5,
#      'temp': 80.1,
#      'maxt': 82.1,
#      'visibility': 5.2,
#      'wspd': 9.2,
#      'severerisk': 12.5,
#      'solarenergy': 0.9,
#      'heatindex': 87.9,
#      'snowdepth': None,
#      'sealevelpressure': 1006.4,
#      'snow': 0.0,
#      'wgust': 18.1,
#      'conditions': 'Rain, Overcast',
#      'windchill': None,
#      'cape': 642.1},
#     {'wdir': 312.4,
#      'uvindex': 2.3,
#      'datetimeStr': '2023-01-30T00:00:00+08:00',
#      'preciptype': '',
#      'cin': -15.0,
#      'cloudcover': 93.1,
#      'pop': 57.1,
#      'mint': 78.5,
#      'datetime': 1675036800000,
#      'precip': 0.89,
#      'solarradiation': 241.3,
#      'dew': 73.7,
#      'humidity': 79.3,
#      'temp': 80.8,
#      'maxt': 83.7,
#      'visibility': 5.0,
#      'wspd': 11.5,
#      'severerisk': 10.0,
#      'solarenergy': 0.9,
#      'heatindex': 90.2,
#      'snowdepth': None,
#      'sealevelpressure': 1006.2,
#      'snow': 0.0,
#      'wgust': 23.0,
#      'conditions': 'Rain, Overcast',
#      'windchill': None,
#      'cape': 729.3}],
#    'id': '1.3521,103.8198',
#    'address': '1.3521,103.8198',
#    'name': '1.3521,103.8198',
#    'index': 0,
#    'latitude': 1.3521,
#    'longitude': 103.8198,
#    'distance': 0.0,
#    'time': 0.0,
#    'tz': 'Asia/Singapore',
#    'currentConditions': {},
#    'alerts': None}}}
